# %%
import os
import pandas as pd
import numpy as np
np.random.seed(42)

# %%
full_df = pd.read_csv("dataset/organized_dataset.csv")

# %%
full_df['categories'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Basic Analysis (Before Processing)

# %%
preferred_categories = [
    "rec.sport.hockey",
    "sci.med",
    "comp.sys.ibm.pc.hardware",
    "talk.religion.misc"
]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
for each_preferred_category in preferred_categories:
    wc = WordCloud().generate(' '.join(full_df[full_df['categories'] == each_preferred_category]['text']))
    plt.figure(figsize=(10, 10))
    plt.title(each_preferred_category, fontsize=30)
    plt.imshow(wc)
